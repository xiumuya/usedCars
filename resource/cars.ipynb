# %%
import requests
from fake_useragent import UserAgent
import json
from tqdm import tqdm
from time import sleep
# fake useragent
ua = UserAgent()

user_agent = ua.random


# add headers 模拟浏览器正常访问请求
headers = {
    "User-Agent": user_agent,
    "Cookie": r"ttwid=1%7CmyHgF6b1xI5ibG3ITgfcq5ZVvIBbT6DE4VNW2h-JS_I%7C1721306154%7Ccead4d9da5b5fe6ae95fd319f1528c3b7199bb03307759ed95e0e3ce3812be28; tt_webid=7392953585342842430; tt_web_version=new; s_v_web_id=verify_lyr98o17_Df8Qunzk_DC92_4Rhh_B5MA_ptTG9CSea0WY; city_name=%E9%87%8D%E5%BA%86; msToken=-A6plihpMHPZ8KdBbgtAgwfzXN7BC68xK4EoeslAj10vvTlg-P6bDp7jDLu92wErp-fezviZiY9-45b_zD6QaTvYmWoMiFRZHXhPgXpl; rit_city=%E5%85%A8%E5%9B%BD; is_dev=false; is_boe=false; Hm_lvt_3e79ab9e4da287b5752d8048743b95e6=1721309659,1721830218; HMACCOUNT=8160C1392AF61C82; _gid=GA1.2.24302535.1721830225; _gat_gtag_UA_138671306_1=1; _ga=GA1.1.427450835.1721306153; _ga_YB3EWSDTGF=GS1.1.1721830224.8.1.1721830244.40.0.0; Hm_lpvt_3e79ab9e4da287b5752d8048743b95e6=1721830245",
}
# add data

data = [{
        "sh_city_name": "全国"
         , "page": int("{}".format(i))
         , "limit": 20
         } for i in range(1, 500 + 1, 1)]

# net
href = (
    r"https://www.dongchedi.com/motor/pc/sh/sh_sku_list?aid=1839&app_name=auto_web_pc"
)



# response
for _ in tqdm(range(len(data))):

    res = requests.post(href, headers=headers, data=data[_])

    # return status code
    res.raise_for_status

    # judge content encoding
    res.encoding = res.apparent_encoding
    # print(res.json())
    sleep(0.5)
    with open ('./json/cars{}.json'.format(_+1), 'w', encoding = "utf-8") as f:
        json.dump(res.json(), f)
# Out:
# 100%|██████████| 500/500 [10:53<00:00,  1.31s/it]

# %%
import os
# find all json files
json_files = []
for root, dirs, files in os.walk('.\json'):
    for file in files:
        if file.endswith('.json'):
            json_files.append(os.path.join(root, file))
json_files[:5]
# Out:
# ['.\\json\\cars1.json',
#  '.\\json\\cars10.json',
#  '.\\json\\cars100.json',
#  '.\\json\\cars101.json',
#  '.\\json\\cars102.json']

# %%
# import os
# from fontTools.ttLib import TTFont
# from PIL import Image, ImageDraw, ImageFont

# # 加载字体文件
# font_path = './SourceHanSansSCBold.ttf'
# font = TTFont(font_path)

# # 创建输出文件夹
# output_folder = './imgs'
# os.makedirs(output_folder, exist_ok=True)

# # 获取 cmap 表
# cmap = font['cmap'].getBestCmap()

# # 提取字形并保存为图像
# for codepoint, glyph_name in cmap.items():
#     # 创建一个新的图像
#     image_size = (200, 200)
#     image = Image.new('L', image_size, color=255)
#     draw = ImageDraw.Draw(image)

#     # 创建字体对象
#     pil_font = ImageFont.truetype(font_path, size=150)

#     # 获取字符
#     char = chr(codepoint)

#     # 绘制字符到图像
#     draw.text((10, 10), char, font=pil_font, fill=0)

#     # 保存图像
#     image.save(os.path.join(output_folder, f'{codepoint:04x}.png'))

# %%
## 不需要运行
# # 由于数据集部分数据乱码 我们可以读取ttf文件，使用ocr工具识别图片，图片由ttf文件切割而来，组成wordMap

# import os
# import re
# from tqdm import tqdm
# from cnocr import CnOcr



# img_files = []
# for root, dirs, files in os.walk(r'./imgs/'):
#     for file in files:
#         if file.endswith('.png'):
#             img_files.append(os.path.join(root, file))
# # print(img_files[:5])

# img_names = [r'\u{}'.format(re.findall(".*imgs/(.*?)[.]png", img)[0]) for img in img_files]
# print(img_names[:5])

# ocr = CnOcr()


# result = [ocr.ocr_for_single_line(img_file)['text'] for img_file in tqdm(img_files)]
# wordM = dict(zip(img_names, result))

# %%
# import re
# wordMap = {}
# with open('wordM.json', 'r') as file:
#     wordMap = json.load(file)

# def replace_(col):
#     for key, value in wordMap.items():
#         col = re.sub(key, value, col)
#     return col

# print(replace_('\ue463\ue54c.\ue45d\ue4e3\ue40a'))

# print(replace_('\ue463.\ue534\ue411\ue40a'))
# from pprint import pprint
# pprint(wordMap)
# Out:
# 21.98万
# 2.65万
# {'\\ue3e8': '候',
#  '\\ue3e9': 'p',
#  '\\ue3ea': '应',
#  '\\ue3eb': '7',
#  '\\ue3ec': '夕',
#  '\\ue3ed': '学',
#  '\\ue3ee': '在',
#  '\\ue3f0': 'X',
#  '\\ue3f1': '着',
#  '\\ue3f2': '原',
#  '\\ue3f3': 'B',
#  '\\ue3f4': '几',
#  '\\ue3f5': '相',
#  '\\ue3f6': 'y',
#  '\\ue3f7': '处',
#  '\\ue3f9': '进',
#  '\\ue3fa': '下',
#  '\\ue3fb': '长',
#  '\\ue3fc': '手',
#  '\\ue3fd': 'w',
#  '\\ue3fe': '花',
#  '\\ue3ff': '后',
#  '\\ue400': 'I',
#  '\\ue401': '发',
#  '\\ue402': '写',
#  '\\ue403': '别',
#  '\\ue404': '期',
#  '\\ue405': '声',
#  '\\ue406': '还',
#  '\\ue407': '友',
#  '\\ue408': 'G',
#  '\\ue409': '些',
#  '\\ue40a': '万',
#  '\\ue40b': 'v',
#  '\\ue40c': '已',
#  '\\ue40d': '路',
#  '\\ue40e': '等',
#  '\\ue40f': '爱',
#  '\\ue410': '每',
#  '\\ue411': '5',
#  '\\ue412': '有',
#  '\\ue413': '结',
#  '\\ue414': '回',
#  '\\ue415': '音',
#  '\\ue416': '像',
#  '\\ue417': '斯',
#  '\\ue418': '比',
#  '\\ue419': '士',
#  '\\ue41a': '现',
#  '\\ue41b': '其',
#  '\\ue41c': '难',
#  '\\ue41d': '4',
#  '\\ue41e': '过',
#  '\\ue41f': '物',
#  '\\ue420': '儿',
#  '\\ue421': '名',
#  '\\ue422': '打',
#  '\\ue423': '都',
#  '\\ue424': '为',
#  '\\ue425': '出',
#  '\\ue426': 'S',
#  '\\ue427': '我',
#  '\\ue428': 'Z',
#  '\\ue42a': '认',
#  '\\ue42b': '道',
#  '\\ue42c': '便',
#  '\\ue42d': '报',
#  '\\ue42e': '一',
#  '\\ue42f': 'h',
#  '\\ue430': '种',
#  '\\ue431': '海',
#  '\\ue432': '将',
#  '\\ue433': '点',
#  '\\ue434': '月',
#  '\\ue435': '员',
#  '\\ue436': '由',
#  '\\ue437': '失',
#  '\\ue438': '同',
#  '\\ue439': '0',
#  '\\ue43a': 't',
#  '\\ue43b': '问',
#  '\\ue43c': '两',
#  '\\ue43d': 'Y',
#  '\\ue43e': 'b',
#  '\\ue43f': '但',
#  '\\ue440': '多',
#  '\\ue441': '然',
#  '\\ue442': '工',
#  '\\ue443': '家',
#  '\\ue444': '才',
#  '\\ue445': '的',
#  '\\ue446': '车',
#  '\\ue447': '轻',
#  '\\ue448': '关',
#  '\\ue449': '看',
#  '\\ue44a': '棱',
#  '\\ue44b': '夫',
#  '\\ue44c': '之',
#  '\\ue44d': '和',
#  '\\ue44e': '真',
#  '\\ue44f': '气',
#  '\\ue450': 'm',
#  '\\ue451': '却',
#  '\\ue452': '法',
#  '\\ue453': '又',
#  '\\ue454': 'j',
#  '\\ue455': '世',
#  '\\ue456': '主',
#  '\\ue457': '己',
#  '\\ue458': '用',
#  '\\ue459': '眼',
#  '\\ue45a': 'k',
#  '\\ue45b': 's',
#  '\\ue45c': '笑',
#  '\\ue45d': '9',
#  '\\ue45e': '格',
#  '\\ue45f': '上',
#  '\\ue460': 'C',
#  '\\ue461': '死',
#  '\\ue462': '亚',
#  '\\ue463': '2',
#  '\\ue464': '四',
#  '\\ue465': '不',
#  '\\ue466': '记',
#  '\\ue467': '者',
#  '\\ue468': '对',
#  '\\ue469': '他',
#  '\\ue46a': '机',
#  '\\ue46b': '能',
#  '\\ue46c': '被',
#  '\\ue46d': '许',
#  '\\ue46e': '国',
#  '\\ue46f': '经',
#  '\\ue470': '从',
#  '\\ue471': '门',
#  '\\ue472': 'L',
#  '\\ue473': 'q',
#  '\\ue474': '那',
#  '\\ue475': '命',
#  '\\ue476': '西',
#  '\\ue478': '往',
#  '\\ue479': '常',
#  '\\ue47a': '电',
#  '\\ue47b': '接',
#  '\\ue47c': '神',
#  '\\ue47d': '望',
#  '\\ue47e': '通',
#  '\\ue47f': '边',
#  '\\ue480': '金',
#  '\\ue481': '男',
#  '\\ue482': 'V',
#  '\\ue483': '全',
#  '\\ue484': '受',
#  '\\ue485': '去',
#  '\\ue486': '拉',
#  '\\ue487': '生',
#  '\\ue488': '部',
#  '\\ue489': '走',
#  '\\ue48a': '作',
#  '\\ue48b': '何',
#  '\\ue48c': '明',
#  '\\ue48d': '乐',
#  '\\ue48e': '成',
#  '\\ue48f': '大',
#  '\\ue490': '地',
#  '\\ue492': '公',
#  '\\ue493': '十',
#  '\\ue494': '这',
#  '\\ue495': '或',
#  '\\ue496': '子',
#  '\\ue497': '先',
#  '\\ue498': '她',
#  '\\ue499': '只',
#  '\\ue49a': '孩',
#  '\\ue49b': '师',
#  '\\ue49c': '所',
#  '\\ue49d': '3',
#  '\\ue49e': '三',
#  '\\ue49f': '东',
#  '\\ue4a0': '了',
#  '\\ue4a1': '意',
#  '\\ue4a2': '老',
#  '\\ue4a3': 'p',
#  '\\ue4a4': 'z',
#  '\\ue4a6': 'H',
#  '\\ue4a7': 'i',
#  '\\ue4a8': '里',
#  '\\ue4a9': 'd',
#  '\\ue4aa': '无',
#  '\\ue4ab': 'J',
#  '\\ue4ac': '满',
#  '\\ue4ae': '变',
#  '\\ue4af': '得',
#  '\\ue4b0': '力',
#  '\\ue4b1': '安',
#  '\\ue4b2': '高',
#  '\\ue4b3': '光',
#  '\\ue4b4': 'Q',
#  '\\ue4b5': '此',
#  '\\ue4b6': '知',
#  '\\ue4b7': '自',
#  '\\ue4b8': '向',
#  '\\ue4b9': '呢',
#  '\\ue4ba': '动',
#  '\\ue4bb': '数',
#  '\\ue4bc': '什',
#  '\\ue4bd': '目',
#  '\\ue4be': '想',
#  '\\ue4bf': '到',
#  '\\ue4c0': '妈',
#  '\\ue4c1': '军',
#  '\\ue4c2': '再',
#  '\\ue4c3': '马',
#  '\\ue4c4': 'O',
#  '\\ue4c5': '听',
#  '\\ue4c6': '使',
#  '\\ue4c7': '吃',
#  '\\ue4c8': '尔',
#  '\\ue4c9': '立',
#  '\\ue4ca': 'g',
#  '\\ue4cb': '因',
#  '\\ue4cc': 'n',
#  '\\ue4cd': '本',
#  '\\ue4ce': 'K',
#  '\\ue4cf': '快',
#  '\\ue4d0': '做',
#  '\\ue4d1': '信',
#  '\\ue4d2': '天',
#  '\\ue4d3': 'M',
#  '\\ue4d4': '至',
#  '\\ue4d5': 'N',
#  '\\ue4d6': '间',
#  '\\ue4d7': '更',
#  '\\ue4d8': '白',
#  '\\ue4d9': '次',
#  '\\ue4da': '条',
#  '\\ue4db': '小',
#  '\\ue4dc': '水',
#  '\\ue4dd': '表',
#  '\\ue4de': '远',
#  '\\ue4df': '面',
#  '\\ue4e0': '告',
#  '\\ue4e1': '象',
#  '\\ue4e2': '加',
#  '\\ue4e3': '8',
#  '\\ue4e4': '民',
#  '\\ue4e5': '直',
#  '\\ue4e6': '住',
#  '\\ue4e7': '理',
#  '\\ue4e8': '色',
#  '\\ue4e9': '让',
#  '\\ue4ea': 'A',
#  '\\ue4eb': '当',
#  '\\ue4ec': '太',
#  '\\ue4ed': '德',
#  '\\ue4ee': '战',
#  '\\ue4ef': 'u',
#  '\\ue4f0': '好',
#  '\\ue4f1': '文',
#  '\\ue4f2': '么',
#  '\\ue4f3': '行',
#  '\\ue4f4': '母',
#  '\\ue4f5': '见',
#  '\\ue4f6': '时',
#  '\\ue4f7': 'F',
#  '\\ue4f8': 'E',
#  '\\ue4f9': 'a',
#  '\\ue4fa': '日',
#  '\\ue4fb': '给',
#  '\\ue4fc': '头',
#  '\\ue4fd': '于',
#  '\\ue4fe': 'r',
#  '\\ue4ff': '利',
#  '\\ue500': '说',
#  '\\ue501': '带',
#  '\\ue503': '克',
#  '\\ue504': '教',
#  '\\ue505': 'o',
#  '\\ue506': '就',
#  '\\ue507': '是',
#  '\\ue508': '最',
#  '\\ue509': '重',
#  '\\ue50a': '实',
#  '\\ue50b': '要',
#  '\\ue50c': '事',
#  '\\ue50d': '总',
#  '\\ue50e': '没',
#  '\\ue50f': '任',
#  '\\ue510': '面',
#  '\\ue511': '话',
#  '\\ue512': '书',
#  '\\ue513': '正',
#  '\\ue514': '口',
#  '\\ue515': '英',
#  '\\ue516': '亲',
#  '\\ue517': 'U',
#  '\\ue518': '度',
#  '\\ue519': '体',
#  '\\ue51a': '活',
#  '\\ue51b': '小',
#  '\\ue51d': '感',
#  '\\ue51e': '前',
#  '\\ue51f': '可',
#  '\\ue520': '中',
#  '\\ue521': '分',
#  '\\ue522': '山',
#  '\\ue523': '你',
#  '\\ue524': '性',
#  '\\ue525': '年',
#  '\\ue526': '情',
#  '\\ue527': '放',
#  '\\ue528': '样',
#  '\\ue529': '叫',
#  '\\ue52a': '起',
#  '\\ue52b': 'c',
#  '\\ue52c': '新',
#  '\\ue52d': '把',
#  '\\ue52e': '开',
#  '\\ue52f': '方',
#  '\\ue530': '女',
#  '\\ue531': '人',
#  '\\ue532': '与',
#  '\\ue533': '身',
#  '\\ue534': '6',
#  '\\ue535': '入',
#  '\\ue536': 'W',
#  '\\ue537': '第',
#  '\\ue538': '父',
#  '\\ue539': '来',
#  '\\ue53a': '界',
#  '\\ue53b': 'D',
#  '\\ue53c': '张',
#  '\\ue53d': '会',
#  '\\ue53e': '美',
#  '\\ue53f': '人',
#  '\\ue540': 'R',
#  '\\ue541': '很',
#  '\\ue542': '风',
#  '\\ue543': 'x',
#  '\\ue545': '内',
#  '\\ue546': '觉',
#  '\\ue547': 'f',
#  '\\ue548': '定',
#  '\\ue549': '果',
#  '\\ue54a': '也',
#  '\\ue54b': '特',
#  '\\ue54c': '1',
#  '\\ue54d': '岁',
#  '\\ue54e': '位',
#  '\\ue54f': '字',
#  '\\ue550': '场',
#  '\\ue551': 'e',
#  '\\ue552': '它',
#  '\\ue553': '门',
#  '\\ue554': '心',
#  '\\ue555': '代',
#  '\\ue556': '解',
#  '\\ue557': '以',
#  '\\ue558': '如',
#  '\\ue559': '并',
#  '\\ue55a': 'T',
#  '\\ue55b': 'l'}

# %%
# 按照上个单元格的wordM 替换对应unicode编码（在原始json文件里）
import json
import re
wordMap = {}
with open('wordM.json', 'r') as file:
    wordMap = json.load(file)

# 1. 读取JSON文件
for jsonPath in json_files:
    with open(jsonPath, 'r') as file:
        content = json.load(file)

    # 2. 将字典转换为字符串
    json_str = json.dumps(content)

    # 3. 使用re.sub按键值对进行替换
    for key, value in wordMap.items():
        # 注意：使用re.escape来处理特殊字符
        json_str = re.sub(re.escape(key), value, json_str)

    # 4. 将字符串转换回字典
    updated_data = json.loads(json_str)

    # 5. 将更新后的字典保存回JSON文件
    with open(r".\json_replace"+jsonPath.split("\\json")[1], 'w') as file:
        json.dump(updated_data, file, indent=4)

# %%
r".\json_replace"+ jsonPath.split("\\json")[1]
# Out:
# '.\\json_replace\\cars99.json'

# %%
# read json file from local
import json
import pandas as pd
import os

# find all json files
json_files_replace = []
for root, dirs, files in os.walk('..\json_replace'):
    for file in files:
        if file.endswith('.json'):
            json_files_replace.append(os.path.join(root, file))
json_files_replace[:5]
data = []


for jsonPath in json_files_replace:
    with open(jsonPath, 'r', encoding='utf-8') as f_:

        car_data = json.load(f_)

        # header names
        Headers = [
            "brand_name"
            , "car_name"
            , "car_source_city_name" # 卖车人的城市
            , "sub_title" # 包含 car_year 和 car_mileage
            , "official_price" #官方价格
            , "sh_price"  # 出售价格
            , 'transfer_cnt' #过户次数
            ]

        data_searched = car_data['data']['search_sh_sku_info_list']

        # memory data

        # print(cars)

        for diclst in data_searched:

            # print(replace_(diclst['sh_price']))

            #还可以使用列表生成式
            # dit = [diclst[col]  if col not in 'official_price and sh_price' else replace_(diclst[col]) for col in Headers]
            dit = {col: diclst[col] for col in Headers}
            # print(dit)
            data.append(dit)

        cars = pd.DataFrame(columns=Headers, data=data)

# %%
cars
# Out:
#      brand_name        car_name car_source_city_name        sub_title  \
# 0           比亚迪      秦EV300 尊享型                   沈阳  2017年 | 6.80万公里
# 1            宝马            X5 M                   北京  2011年 | 6.72万公里
# 2            众泰    2.0T 自动极致之心版                   广州  2018年 | 3.90万公里
# 3          雷克萨斯        300e 纯·悦                   南昌  2021年 | 3.24万公里
# 4           雪佛兰   RS 330T 自动畅快版                   杭州  2019年 | 4.34万公里
# ...         ...             ...                  ...              ...
# 9989       吉利汽车       1.8T 领航版+                   昆明  2021年 | 4.21万公里
# 9990         奔驰  E 300 L 豪华型 轿车                   苏州  2022年 | 2.10万公里
# 9991         红旗     1.5T DCT旗韵版                   郑州  2022年 | 2.31万公里
# 9992         奔驰         GLA 200                   贵阳  2022年 | 3.60万公里
# 9993      北汽新能源       EV160 轻快版                   青岛     2017年 | 5万公里
#
#      official_price sh_price  transfer_cnt
# 0            24.59万    3.68万             3
# 1           201.80万   15.98万             4
# 2            15.18万    3.18万             0
# 3            36.20万   11.98万             0
# 4            11.49万    3.88万             0
# ...             ...      ...           ...
# 9989         13.68万    7.18万             2
# 9990         50.41万   38.88万             0
# 9991         14.88万    9.01万             0
# 9992         30.38万   17.20万             0
# 9993         17.78万    1.98万             2
#
# [9994 rows x 7 columns]

# %%
# cars["brand_name"] = cars["brand_name"].apply(replace_)
# cars["car_name"] = cars["car_name"].apply(replace_)
# cars["car_source_city_name_name"] = cars["car_source_city_name"].apply(replace_)
# cars["sub_title"] = cars["sub_title"].apply(replace_)
# cars["official_price"] = cars["official_price"].apply(replace_)
# cars["sh_price"] = cars["sh_price"].apply(replace_)
# cars["transfer_cnt"] = cars["transfer_cnt"].apply(replace_)

# %%
# 分割字段 subtitle
split_df = cars['sub_title'].str.split('|', expand=True)

# 将分割后的 DataFrame 列分别赋值给新的字段
cars['car_year'] = split_df[0]
cars['car_mileage'] = split_df[1]

nullSUMDF = cars.isnull().sum().sort_values(ascending=False).to_frame("nullCount")
display(nullSUMDF)
cars.dropna(inplace=True)
cars['car_mileage'] = cars["car_mileage"].apply(lambda x: x.strip())
cars['car_year'] = cars["car_year"].apply(lambda x: x.strip())

cars.drop(columns="sub_title", inplace=True)

cars.to_csv(r'../used_cars.csv', index=False, header=True)
cars
# Out:
#                       nullCount
# car_mileage                   1
# brand_name                    0
# car_name                      0
# car_source_city_name          0
# sub_title                     0
# official_price                0
# sh_price                      0
# transfer_cnt                  0
# car_year                      0
#      brand_name        car_name car_source_city_name official_price sh_price  \
# 0           比亚迪      秦EV300 尊享型                   沈阳         24.59万    3.68万
# 1            宝马            X5 M                   北京        201.80万   15.98万
# 2            众泰    2.0T 自动极致之心版                   广州         15.18万    3.18万
# 3          雷克萨斯        300e 纯·悦                   南昌         36.20万   11.98万
# 4           雪佛兰   RS 330T 自动畅快版                   杭州         11.49万    3.88万
# ...         ...             ...                  ...            ...      ...
# 9989       吉利汽车       1.8T 领航版+                   昆明         13.68万    7.18万
# 9990         奔驰  E 300 L 豪华型 轿车                   苏州         50.41万   38.88万
# 9991         红旗     1.5T DCT旗韵版                   郑州         14.88万    9.01万
# 9992         奔驰         GLA 200                   贵阳         30.38万   17.20万
# 9993      北汽新能源       EV160 轻快版                   青岛         17.78万    1.98万
#
#       transfer_cnt car_year car_mileage
# 0                3    2017年     6.80万公里
# 1                4    2011年     6.72万公里
# 2                0    2018年     3.90万公里
# 3                0    2021年     3.24万公里
# 4                0    2019年     4.34万公里
# ...            ...      ...         ...
# 9989             2    2021年     4.21万公里
# 9990             0    2022年     2.10万公里
# 9991             0    2022年     2.31万公里
# 9992             0    2022年     3.60万公里
# 9993             2    2017年        5万公里
#
# [9993 rows x 8 columns]

# %%
## 数据集仍然有部分乱码，``需要删除`` 好像没有了。
cars
# Out:
#      brand_name        car_name car_source_city_name official_price sh_price  \
# 0           比亚迪      秦EV300 尊享型                   沈阳         24.59万    3.68万
# 1            宝马            X5 M                   北京        201.80万   15.98万
# 2            众泰    2.0T 自动极致之心版                   广州         15.18万    3.18万
# 3          雷克萨斯        300e 纯·悦                   南昌         36.20万   11.98万
# 4           雪佛兰   RS 330T 自动畅快版                   杭州         11.49万    3.88万
# ...         ...             ...                  ...            ...      ...
# 9989       吉利汽车       1.8T 领航版+                   昆明         13.68万    7.18万
# 9990         奔驰  E 300 L 豪华型 轿车                   苏州         50.41万   38.88万
# 9991         红旗     1.5T DCT旗韵版                   郑州         14.88万    9.01万
# 9992         奔驰         GLA 200                   贵阳         30.38万   17.20万
# 9993      北汽新能源       EV160 轻快版                   青岛         17.78万    1.98万
#
#       transfer_cnt car_year car_mileage
# 0                3    2017年     6.80万公里
# 1                4    2011年     6.72万公里
# 2                0    2018年     3.90万公里
# 3                0    2021年     3.24万公里
# 4                0    2019年     4.34万公里
# ...            ...      ...         ...
# 9989             2    2021年     4.21万公里
# 9990             0    2022年     2.10万公里
# 9991             0    2022年     2.31万公里
# 9992             0    2022年     3.60万公里
# 9993             2    2017年        5万公里
#
# [9993 rows x 8 columns]

# %%
## 数据预处理部分
cars["brand_name"].unique()
cars = cars[[
              'brand_name'
            , 'car_name'
            , 'car_source_city_name'
            , 'car_year'
            , 'car_mileage'
            , 'transfer_cnt'
            , 'official_price'
            , 'sh_price']]
# 如果除sh_price列之外其余列数据相同，则去除后一行数据
## 去除相同数据，确保sh_price只有唯一的参数与之对应
cars = cars.sort_values("brand_name", ignore_index=True)
cars_duplicated = cars.drop_duplicates(subset = cars.columns[:-1], keep='first')
cars_duplicated
# Out:
#      brand_name        car_name car_source_city_name car_year car_mileage  \
# 0           212  狙击手 2.4T 手动轻装款                   南京    2023年     0.60万公里
# 1          AITO         增程四驱智驾版                   武汉    2023年     1.35万公里
# 2          AITO       Plus五座后驱版                   南京    2023年     2.40万公里
# 3          AITO       Plus五座四驱版                   惠州    2023年     1.20万公里
# 4          AITO       Plus五座四驱版                   合肥    2023年     1.17万公里
# ...         ...             ...                  ...      ...         ...
# 9988         魏牌        2.0T 科技版                   上海    2020年     5.85万公里
# 9989         魏牌     1.5T DHT超大杯                   三亚    2023年     3.50万公里
# 9990         魏牌        2.0T 豪华型                   广州    2019年     4.70万公里
# 9991         魏牌        1.5T 智先锋                   银川    2020年     7.50万公里
# 9992         魏牌        1.5T 智先锋                   商丘    2021年     1.82万公里
#
#       transfer_cnt official_price sh_price
# 0                0          9.99万    7.98万
# 1                0         29.98万   18.88万
# 2                0         24.98万   19.28万
# 3                0         28.48万   21.38万
# 4                0         28.48万   21.90万
# ...            ...            ...      ...
# 9988             0         19.28万    7.69万
# 9989             0         18.98万   11.30万
# 9990             2         16.98万    5.00万
# 9991             1         13.78万    7.65万
# 9992             2         13.78万    7.38万
#
# [9905 rows x 8 columns]
